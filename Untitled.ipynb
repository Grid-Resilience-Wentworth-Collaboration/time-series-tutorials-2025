# %%
import pandas as pd
from pmdarima import auto_arima
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 15

# %%
# Load the data
file_path = 'data/BTC-USD.csv'
df = pd.read_csv(file_path, index_col = "Date", parse_dates = True).asfreq("D")
df.head
# Out:
# <bound method NDFrame.head of                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2024-02-12  48296.386719  50280.476563  47745.761719  49958.222656
# 2024-02-13  49941.359375  50358.390625  48406.496094  49742.441406
# 2024-02-14  49733.445313  52021.371094  49296.832031  51826.695313
# 2024-02-15  51836.785156  52820.066406  51371.628906  51938.554688
# 2024-02-16  51937.726563  52365.917969  51767.210938  51841.062500
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# ...

# %%
training = df.iloc[:-60,:]
test = df.iloc[-60:,:]

# %%
model = auto_arima(y = training.Close, m = 7)
# Out:
# C:\Users\mckays1\OneDrive - Wentworth Institute of Technology\Documents\GithubRedownload\time-series-tutorials-2025\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\mckays1\OneDrive - Wentworth Institute of Technology\Documents\GithubRedownload\time-series-tutorials-2025\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\mckays1\OneDrive - Wentworth Institute of Technology\Documents\GithubRedownload\time-series-tutorials-2025\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
predictions = pd.Series(model.predict(n_periods = len(test)))
predictions.index = test.index
predictions[:14]
# Out:
# C:\Users\mckays1\OneDrive - Wentworth Institute of Technology\Documents\GithubRedownload\time-series-tutorials-2025\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Date
# 2023-12-19    42590.936027
# 2023-12-20    42467.951019
# 2023-12-21    42475.322255
# 2023-12-22    42573.611944
# 2023-12-23    42625.825935
# 2023-12-24    42630.791747
# 2023-12-25    42447.588768
# 2023-12-26    42376.363167
# 2023-12-27    42447.376417
# 2023-12-28    42516.545447
# 2023-12-29    42540.512122
# 2023-12-30    42525.697896
# 2023-12-31    42452.378139
# 2024-01-01    42540.261758
# Freq: D, dtype: float64

# %%
training['High']['2023'].plot(figsize = (12,8), legend = True)
test['High'].plot(legend = True)
predictions.plot(legend = True)
# Out:
# <Axes: xlabel='Date'>
