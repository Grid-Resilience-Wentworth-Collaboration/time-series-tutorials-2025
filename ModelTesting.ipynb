# 2021-11-02  63226.402344  37746665647
# 2021-11-03  62970.046875  36124731509
# 2021-11-04  61452.230469  32615846901
# 2021-11-05  61125.675781  30605102446
# 2021-11-06  61527.480469  29094934221
# 2021-11-07  63326.988281  24726754302
# 2021-11-08  67566.828125  41125608330
# 2021-11-09  66971.828125  42357991721
# 2021-11-10  64995.230469  48730828378
# 2021-11-11  64949.960938  35880633236
# 2021-11-12  64155.941406  36084893887
# 2021-11-13  64469.527344  30474228777
# 2021-11-14  65466.839844  25122092191
# 2021-11-15  63557.871094  30558763548
# 2021-11-16  60161.246094  46844335592
# 2021-11-17  60368.011719  39178392930
# 2021-11-18  56942.136719  41388338699
# 2021-11-19  58119.578125  38702407772
# 2021-11-20  59697.195313  30624264863
# 2021-11-21  58730.476563  26123447605
# 2021-11-22  56289.289063  35036121783
# 2021-11-23  57569.074219  37485803899
# 2021-11-24  56280.425781  36635566789
# 2021-11-25  57274.679688  34284016248
# 2021-11-26  53569.765625  41810748221
# 2021-11-27  54815.078125  30560857714
# 2021-11-28  57248.457031  28116886357
# 2021-11-29  57806.566406  32370840356
# 2021-11-30  57005.425781  36708594618

# %%
df1 = pd.read_csv("data/BTC-USD.csv", index_col = "Date", parse_dates = True)
df1.index
# Out:
# DatetimeIndex(['2014-09-17', '2014-09-18', '2014-09-19', '2014-09-20',
#                '2014-09-21', '2014-09-22', '2014-09-23', '2014-09-24',
#                '2014-09-25', '2014-09-26',
#                ...
#                '2024-02-07', '2024-02-08', '2024-02-09', '2024-02-10',
#                '2024-02-11', '2024-02-12', '2024-02-13', '2024-02-14',
#                '2024-02-15', '2024-02-16'],
#               dtype='datetime64[ns]', name='Date', length=3440, freq=None)

# %%
df.resample('W').mean()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-21    429.916998    437.718194    406.624402    416.859003
# 2014-09-28    410.650718    418.668993    399.377141    407.692566
# 2014-10-05    369.774288    376.721000    353.207140    361.426570
# 2014-10-12    346.927429    363.308864    337.567858    355.234580
# 2014-10-19    389.010284    397.790427    380.410575    390.479854
# ...                  ...           ...           ...           ...
# 2024-01-21  42094.765067  42688.522321  41407.597656  42071.628906
# 2024-01-28  40700.582589  41388.431362  39997.193638  40762.331473
# 2024-02-04  42872.099889  43426.494420  42365.402344  42951.560826
# 2024-02-11  44696.719308  45941.541853  44526.495536  45510.789063
# 2024-02-18  50349.140625  51569.244531  49717.585938  51061.395313
#
#                Adj Close        Volume
# Date
# 2014-09-21    416.859003  3.138068e+07
# 2014-09-28    407.692566  2.668180e+07
# 2014-10-05    361.426570  3.952256e+07
# 2014-10-12    355.234580  4.873611e+07
# 2014-10-19    390.479854  2.241458e+07
# ...                  ...           ...
# 2024-01-21  42071.628906  1.987655e+10
# 2024-01-28  40762.331473  2.218780e+10
# 2024-02-04  42951.560826  1.931203e+10
# 2024-02-11  45510.789063  2.254663e+10
# 2024-02-18  51061.395313  3.659387e+10
#
# [492 rows x 6 columns]

# %%
df['7_day_rolling'] = df['Close'].rolling(window = 7).mean()
df[['Close', '7_day_rolling']].loc['2023'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample('ME').mean()['Close'].idxmax()
# Out:
# Timestamp('2021-11-30 00:00:00')

# %%
df['daily_returns'] = df['Close'].pct_change()*100

# %%
df[abs(df['daily_returns']) > 10].head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-11-12  367.984985  429.717987  367.984985  423.561005  423.561005
# 2015-01-03  314.846008  315.149994  281.082001  281.082001  281.082001
# 2015-01-13  267.394012  268.277008  219.906006  225.860992  225.860992
# 2015-01-14  223.893997  223.893997  171.509995  178.102997  178.102997
# 2015-01-15  176.897003  229.067001  176.897003  209.843994  209.843994
#
#               Volume  7_day_rolling  daily_returns
# Date
# 2014-11-12  45783200     365.519579      15.193570
# 2015-01-03  33054400     310.171718     -10.776686
# 2015-01-13  72843904     271.743853     -15.659308
# 2015-01-14  97638704     255.138995     -21.144862
# 2015-01-15  81773504     244.638280      17.821709

# %%
df['Close'].plot(title = 'Daily Closing Price')
# Out:
# <Axes: title={'center': 'Daily Closing Price'}, xlabel='Date'>

# %%
df.resample('YE').sum()['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['30_day_rolling_vol'] = df['Volume'].rolling(window = 30).mean()
df['30_day_rolling_vol'].plot(legend = True, ylabel = 'Volume')
ax = df['Close'].plot(secondary_y = True, legend = True)
ax.set_ylabel('Closing Price')
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
df[['Close','30_day_rolling_vol']].corr()
#Correlation between close and rolling vol
# Out:
#                        Close  30_day_rolling_vol
# Close               1.000000            0.744147
# 30_day_rolling_vol  0.744147            1.000000

# %%
df.isnull().sum()

#Fill Missing values
df['30_day_rolling_vol'].bfill() 

df.isnull().sum()
# Out:
# Open                   0
# High                   0
# Low                    0
# Close                  0
# Adj Close              0
# Volume                 0
# 7_day_rolling          6
# daily_returns          1
# 30_day_rolling_vol    29
# dtype: int64

# %%
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df['weekday'] = df.index.day_name()
df['weekday_numeric'] = df.index.weekday
df['is_weekend'] = df.index.weekday>4
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume  7_day_rolling  daily_returns  30_day_rolling_vol  year  \
# Date
# 2014-09-17  21056800            NaN            NaN                 NaN  2014
# 2014-09-18  34483200            NaN      -7.192558                 NaN  2014
# 2014-09-19  37919700            NaN      -6.984264                 NaN  2014
# 2014-09-20  36863600            NaN       3.573492                 NaN  2014
# 2014-09-21  26580100            NaN      -2.465855                 NaN  2014
#
#             month  day    weekday  weekday_numeric  is_weekend
# Date
# 2014-09-17      9   17  Wednesday                2       False
# 2014-09-18      9   18   Thursday                3       False
# 2014-09-19      9   19     Friday                4       False
# 2014-09-20      9   20   Saturday                5        True
# 2014-09-21      9   21     Sunday                6        True

# %%
df['closed_lag1'] = df['Close'].shift(1)
df['closed_lag2'] = df['Close'].shift(2)

# %%
from statsmodels.graphics.tsaplots import month_plot, quarter_plot

# %%
month_plot(df['Close'].resample('ME').mean(),ylabel = 'Closing')

# %%
quarter_plot(df['Close'].resample('QE').mean(),ylabel = 'Closing')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp = seasonal_decompose(df['Close'], model = 'multiplicative', period = 365)
fig = decomp.plot()
