# %%
import pandas as pd

# %%
df = pd.read_csv('data/BTC-USD.csv')
df.head()
# Out:
#         pDate        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
df['pDate'] = pd.to_datetime(df['pDate'], format = "%Y-%m-%d")
df.set_index('pDate', inplace = True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# pDate
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume
# pDate
# 2014-09-17  21056800
# 2014-09-18  34483200
# 2014-09-19  37919700
# 2014-09-20  36863600
# 2014-09-21  26580100

# %%
df.loc['2021-11']
# Out:
#                     Open          High           Low         Close  \
# pDate
# 2021-11-01  61320.449219  62419.003906  59695.183594  61004.406250
# 2021-11-02  60963.253906  64242.792969  60673.054688  63226.402344
# 2021-11-03  63254.335938  63516.937500  61184.238281  62970.046875
# 2021-11-04  62941.804688  63123.289063  60799.664063  61452.230469
# 2021-11-05  61460.078125  62541.468750  60844.609375  61125.675781
# 2021-11-06  61068.875000  61590.683594  60163.781250  61527.480469
# 2021-11-07  61554.921875  63326.988281  61432.488281  63326.988281
# 2021-11-08  63344.066406  67673.742188  63344.066406  67566.828125
# 2021-11-09  67549.734375  68530.335938  66382.062500  66971.828125
# 2021-11-10  66953.335938  68789.625000  63208.113281  64995.230469
# 2021-11-11  64978.890625  65579.015625  64180.488281  64949.960938
# 2021-11-12  64863.980469  65460.816406  62333.914063  64155.941406
# 2021-11-13  64158.121094  64915.675781  63303.734375  64469.527344
# ...

# %%
df1 = pd.read_csv("data/BTC-USD.csv", index_col = "pDate", parse_dates = True)
df1.index
# Out:
# DatetimeIndex(['2014-09-17', '2014-09-18', '2014-09-19', '2014-09-20',
#                '2014-09-21', '2014-09-22', '2014-09-23', '2014-09-24',
#                '2014-09-25', '2014-09-26',
#                ...
#                '2024-02-07', '2024-02-08', '2024-02-09', '2024-02-10',
#                '2024-02-11', '2024-02-12', '2024-02-13', '2024-02-14',
#                '2024-02-15', '2024-02-16'],
#               dtype='datetime64[ns]', name='pDate', length=3440, freq=None)

# %%
df.resample('W').mean()
# Out:
#                     Open          High           Low         Close  \
# pDate
# 2014-09-21    429.916998    437.718194    406.624402    416.859003
# 2014-09-28    410.650718    418.668993    399.377141    407.692566
# 2014-10-05    369.774288    376.721000    353.207140    361.426570
# 2014-10-12    346.927429    363.308864    337.567858    355.234580
# 2014-10-19    389.010284    397.790427    380.410575    390.479854
# ...                  ...           ...           ...           ...
# 2024-01-21  42094.765067  42688.522321  41407.597656  42071.628906
# 2024-01-28  40700.582589  41388.431362  39997.193638  40762.331473
# 2024-02-04  42872.099889  43426.494420  42365.402344  42951.560826
# 2024-02-11  44696.719308  45941.541853  44526.495536  45510.789063
# 2024-02-18  50349.140625  51569.244531  49717.585938  51061.395313
#
#                Adj Close        Volume  7_day_rolling
# pDate
# 2014-09-21    416.859003  3.138068e+07            NaN
# ...

# %%
df['7_day_rolling'] = df['Close'].rolling(window = 7).mean()
df[['Close', '7_day_rolling']].plot)
